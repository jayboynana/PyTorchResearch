# %% [markdown]
# ### Simple NeuralNetWork

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor

# %%
device = ("cuda" if torch.cuda.is_available() else "cpu")

# %%
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
#building basic and simple neural network
class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()
        self.linear_relu = nn.Sequential(
            nn.Linear(28*28,512),
            nn.ReLU(),
            nn.Linear(512,512),
            nn.ReLU(),
            nn.Linear(512,10)
        )
        
    def forward(self,x):
        x = self.flatten(x)
        logits = self.linear_relu(x)
        return logits
    
model = NeuralNetwork().to(device)
print(model)
# Out:
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu): Sequential(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=10, bias=True)
#   )
# )

# %%
X = torch.randn(1,28,28,device = device)

# %%
X
# Out:
# tensor([[[ 6.1199e-01, -1.1942e+00, -1.8030e-01, -4.0019e-01, -1.9106e-01,
#            8.0851e-01, -1.0430e+00,  1.5764e-03, -1.6570e-01,  7.0914e-01,
#           -8.9350e-01,  9.4710e-01,  2.5992e+00, -2.1815e-02, -1.1367e-01,
#            1.3267e+00,  8.2591e-01,  9.2536e-01, -1.5196e-01, -3.1309e-01,
#            1.8107e+00, -1.1350e+00,  3.4214e-01,  2.5071e-01,  1.8806e+00,
#           -5.6765e-01,  2.9658e-01,  1.1336e+00],
#          [-1.0434e-01, -2.0928e-01,  4.2977e-01, -3.9349e-01,  8.9993e-02,
#            3.6427e-01,  1.4881e+00,  1.5545e+00,  8.2478e-02, -5.2435e-02,
#            8.6251e-01,  1.2952e-01,  3.5314e-01, -5.3875e-01, -3.4002e-01,
#            2.3986e-01, -2.4635e-01, -6.7913e-01,  9.0027e-01,  3.0231e-01,
#           -1.9723e+00, -3.5731e-01,  1.9605e+00,  8.9374e-01,  7.2737e-01,
#            1.4710e+00, -7.4228e-01, -1.7998e-01],
#          [ 1.0619e+00,  8.8477e-01, -4.6720e-01, -7.6493e-01, -4.2835e-01,
#            1.6213e-01, -5.0706e-01,  7.2560e-02,  1.7978e+00,  3.6197e-01,
#            4.9255e-01,  5.7230e-02, -1.2473e+00,  1.6133e+00, -5.9801e-01,
#            8.4889e-01, -2.9464e-01, -7.9359e-01, -4.8204e-01,  1.3936e+00,
#            1.5403e+00,  8.7944e-02, -1.0336e+00, -5.2544e-01, -2.3945e-01,
#           -1.8625e+00, -1.7462e+00,  1.2602e+00],
#          [-1.8615e+00,  1.1188e+00,  1.0982e+00,  9.9936e-01, -4.6975e-01,
#           -1.0206e+00,  8.9088e-02,  1.0085e-01, -3.2361e-01, -4.3856e-01,
#            1.3017e+00, -9.3515e-02, -2.3234e-01, -2.6218e+00, -5.4699e-01,
#            1.6539e+00, -6.1275e-01, -9.4534e-02, -6.3929e-01,  1.8758e+00,
#           -7.2491e-01, -6.3180e-01,  4.3410e-01, -2.3579e-01, -1.3669e+00,
#            1.4408e-01, -3.3611e-02, -1.3963e-01],
#          [-2.7970e-01, -2.6050e-01, -1.4391e+00,  8.9852e-01,  1.1632e+00,
#           -9.1666e-01,  1.3845e+00, -1.3418e+00, -3.6459e-01,  1.3594e+00,
#            6.8121e-01, -9.6338e-02, -8.5896e-01, -1.9203e+00,  1.0334e-01,
#           -4.6993e-01, -1.4466e+00,  2.9273e-01,  9.8005e-01,  1.8220e+00,
#            2.9372e-01, -3.3639e-01, -9.6553e-01,  1.1140e+00, -1.3342e+00,
#           -7.5060e-01,  8.6961e-01, -9.6083e-01],
#           -2.7732e+00,  9.2980e-01,  3.6955e-01],
#          [-2.5714e-01, -8.2894e-01, -8.6132e-01,  4.4959e-01, -5.5754e-01,
#            1.5987e+00,  1.2754e+00, -7.1530e-01, -3.9640e-01,  9.0260e-01,
#            1.9649e-02, -2.6334e-01,  2.0877e-01,  3.5585e-01, -6.5103e-01,
#           -5.7794e-01, -1.2017e+00,  2.0558e-01, -1.3863e+00, -6.2771e-01,
#           -7.7744e-02,  4.6459e-01,  1.5575e+00, -1.5758e+00, -3.9674e-01,
#           -4.6651e-01,  2.4213e-01,  3.9450e-01],
#          [ 7.5183e-01, -6.1200e-01,  5.7488e-01,  8.5302e-02, -2.8144e-01,
#           -2.0956e+00,  1.7440e+00, -1.0824e+00, -8.9360e-01, -1.0722e+00,
#           -7.3705e-01, -2.3882e+00, -6.9570e-01, -1.3442e-01,  1.3649e+00,
#            2.6654e+00, -6.7493e-01, -1.2231e+00, -1.1310e+00,  1.1853e-01,
#           -4.4710e-01,  2.6311e-01, -2.1474e-01,  7.7887e-01, -1.2683e+00,
#            1.1723e+00, -6.9853e-01,  1.5655e+00],
#          [-1.5086e+00,  5.5551e-01, -1.7647e-01, -1.3857e+00, -9.2003e-01,
#            2.0999e+00,  2.1165e+00, -3.8160e-01,  1.6123e+00, -1.2298e+00,
#            1.0796e+00, -1.0737e+00,  8.2876e-01,  9.2079e-01, -5.2701e-01,
#            1.8394e-02,  5.7200e-02, -1.9392e+00, -5.2888e-01,  6.5910e-01,
#           -1.4188e+00,  1.2579e+00,  9.7335e-01, -7.9259e-01,  1.9768e-01,
#           -4.4535e-01,  5.4846e-01, -1.5867e-01],
#          [ 1.2990e+00,  1.7026e-01,  2.8632e-01, -9.3944e-01,  1.0903e+00,
#           -7.2216e-01,  2.0699e-01, -5.7407e-01,  9.3355e-01, -7.6786e-01,
#            7.2274e-01,  6.8648e-01, -6.2264e-01,  1.7361e+00, -2.1871e+00,
#           -3.9359e-01,  1.7361e+00,  1.2087e+00, -1.3461e+00, -5.7436e-01,
#            1.3496e+00, -1.8581e-01,  5.9990e-01,  2.1345e+00,  2.2190e+00,
#            1.3845e+00,  2.2581e-01,  7.3278e-02],
#          [ 1.5420e+00, -3.1201e-01, -7.7122e-01, -6.3209e-01, -7.2373e-01,
#            2.3850e+00,  1.7625e+00, -1.6573e-01, -6.0341e-01,  7.8013e-01,
#           -1.1941e+00, -1.3293e+00,  3.1257e-01,  1.7022e-01, -2.5395e-01,
#           -4.7773e-01,  2.2418e-01, -1.0870e+00,  1.7356e+00,  3.2966e-01,
#           -2.8725e+00, -3.9353e-01, -2.3896e-01,  2.8357e-01, -1.1125e+00,
#           -3.7629e-01,  1.7919e+00, -1.9100e-02]]])

# %%
logits = model(X)

# %%
softmax = nn.Softmax(dim = 1)

# %%
pred_probab = softmax(logits)
y_pred = pred_probab.argmax(1)

# %%
print(pred_probab)
print(y_pred)
# Out:
# tensor([[0.1207, 0.0940, 0.0908, 0.1027, 0.1023, 0.1139, 0.1044, 0.0891, 0.0889,
#          0.0931]], device='cuda:0', grad_fn=<SoftmaxBackward0>)
# tensor([0], device='cuda:0')

# %%
X2 = torch.randn(10,28,28,device = device)

# %%
logits2 = model(X2)

# %%
pred_probab2 = softmax(logits2)
y_pred2 = pred_probab2.argmax(1)

# %%
print(pred_probab2)
print(y_pred2)
# Out:
# tensor([[0.1115, 0.0959, 0.0936, 0.0948, 0.1109, 0.1058, 0.1031, 0.0929, 0.0994,
#          0.0920],
#         [0.1095, 0.0920, 0.0904, 0.1029, 0.0964, 0.1123, 0.1015, 0.0961, 0.1035,
#          0.0954],
#         [0.1169, 0.1081, 0.0907, 0.0956, 0.0919, 0.1034, 0.0890, 0.1012, 0.1062,
#          0.0969],
#         [0.1083, 0.0911, 0.0947, 0.1008, 0.1018, 0.0986, 0.0958, 0.0918, 0.1137,
#          0.1034],
#         [0.1060, 0.0973, 0.0879, 0.0976, 0.1017, 0.0988, 0.1135, 0.0909, 0.0976,
#          0.1087],
#         [0.1036, 0.1002, 0.0890, 0.0990, 0.0999, 0.1103, 0.1116, 0.0893, 0.1101,
#          0.0869],
#         [0.0998, 0.1011, 0.0869, 0.1040, 0.0990, 0.1177, 0.1016, 0.0986, 0.1056,
#          0.0857],
#         [0.1081, 0.0925, 0.0921, 0.1117, 0.1122, 0.0940, 0.1112, 0.0848, 0.0930,
#          0.1004],
#         [0.1033, 0.1035, 0.0869, 0.0986, 0.0996, 0.1070, 0.0930, 0.0993, 0.1001,
#          0.1087],
#         [0.1056, 0.0905, 0.0831, 0.1110, 0.1058, 0.1016, 0.1047, 0.0874, 0.1118,
#          0.0985]], device='cuda:0', grad_fn=<SoftmaxBackward0>)
# tensor([0, 5, 0, 8, 6, 6, 5, 4, 9, 8], device='cuda:0')

# %%
#Model Parameters
for name, parameter in model.named_parameters():
    # print(f"layer name:{name} | size:{parameter.size()} | values:{parameter[:2]}")
    print(f" layer name:{name} \n size:{parameter.size()} \n values:{parameter[:2]} \n")
    # print(f" layer name:{name} \n size:{parameter.size()} \n values:{parameter[:2]} \n shape:{parameter[:2].shape}\n")
# Out:
#  layer name:linear_relu.0.weight
#  size:torch.Size([512, 784])
#  values:tensor([[-0.0123,  0.0006,  0.0081,  ...,  0.0237, -0.0279, -0.0138],
#         [ 0.0202, -0.0187,  0.0337,  ..., -0.0250,  0.0039,  0.0160]],
#        device='cuda:0', grad_fn=<SliceBackward0>)
#
#  layer name:linear_relu.0.bias
#  size:torch.Size([512])
#  values:tensor([-0.0083,  0.0321], device='cuda:0', grad_fn=<SliceBackward0>)
#
#  layer name:linear_relu.2.weight
#  size:torch.Size([512, 512])
#  values:tensor([[ 0.0100, -0.0273,  0.0083,  ..., -0.0287, -0.0273, -0.0099],
#         [-0.0250, -0.0231, -0.0131,  ...,  0.0011,  0.0376, -0.0348]],
#        device='cuda:0', grad_fn=<SliceBackward0>)
#
#  layer name:linear_relu.2.bias
#  size:torch.Size([512])
#  values:tensor([-0.0413,  0.0062], device='cuda:0', grad_fn=<SliceBackward0>)
#
#  layer name:linear_relu.4.weight
#  size:torch.Size([10, 512])
#  values:tensor([[ 0.0265,  0.0197,  0.0030,  ...,  0.0387,  0.0219,  0.0028],
#         [-0.0201, -0.0216, -0.0297,  ...,  0.0242, -0.0011, -0.0216]],
#        device='cuda:0', grad_fn=<SliceBackward0>)
#
#  layer name:linear_relu.4.bias
#  size:torch.Size([10])
#  values:tensor([0.0241, 0.0269], device='cuda:0', grad_fn=<SliceBackward0>)
